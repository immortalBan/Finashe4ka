# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT student_id || ';' || upper(surname) || ';' || upper(name) || ';' || stipend || ';' || upper(city) || ';' || TO_CHAR(birthday, 'DD/MM/YYYY') || ';' || univ_id
#     FROM student;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT substr(surname, 1, 1) || '.' || upper(name) || '; ' || 'место жительства' || '-' || upper(city) || '; ' || 'родился' || '-' || TO_CHAR(birthday, 'DD.MM.YY')
#     FROM student;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT substr(lower(surname), 1, 1) || '.' || lower(name) || '; ' || 'место жительства' || '-' || lower(city) || '; ' || 'родился' || '-' || TO_CHAR(birthday, 'DD-Mon-YYYY')
#     FROM student;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT name || ' ' || surname || ' родился в ' ||  TO_CHAR(birthday, 'YYYY') || ' году'
#     FROM student;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT surname, name, stipend*100
#     FROM student;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT lower(surname), lower(name), stipend*100
#     FROM student
#     WHERE kurs in (1, 2, 4);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT 'Код-' || univ_id || '; ' || univ_name || '-г.' || city || '; Рейтинг=' || rating
#     FROM university;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT 'Код-' || univ_id || '; ' || univ_name || '-г.' || city || '; Рейтинг=' || round(rating, -2)
#     FROM university;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT count(student_id)
#     FROM exam_marks
#     WHERE exam_id = 20;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT count(DISTINCT subj_id)
#     FROM exam_marks;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT student_id, MIN(mark)
#     FROM exam_marks
#     GROUP BY student_id;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT student_id, MAX(mark)
#     FROM exam_marks
#     GROUP BY student_id;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT surname
#     FROM student
#     WHERE surname LIKE 'И%'
#     ORDER BY surname
#     LIMIT 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT subj_name, semester
#     FROM subject;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT exam_date, count(*)
#     FROM exam_marks
#     GROUP BY exam_date;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT student.kurs, AVG(exam_marks.mark), exam_marks.subj_id
#     FROM student
#     INNER JOIN exam_marks ON student.student_id=exam_marks.student_id
#     GROUP BY exam_marks.subj_id

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT student.student_id, AVG(exam_marks.mark)
#     FROM student
#     INNER JOIN exam_marks ON student.student_id=exam_marks.student_id
#     GROUP BY exam_marks.student_id

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT exam_marks.exam_id, AVG(exam_marks.mark)
#     FROM exam_marks
#     GROUP BY exam_marks.exam_id

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT exam_id, count(*)
#     FROM exam_marks
#     GROUP BY exam_id;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT (semester + 1) / 2 as kurs, count(*) as 'Кол-во предметов'
#     FROM subject
#     GROUP BY kurs;
