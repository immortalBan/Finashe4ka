# %%
import pandas as pd

# %%
#Считать файл в pandas DataFrame
df = pd.read_csv('Titanic.csv')
df
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived
# 0            1
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 1308         0
# 1309         0
# 1310         0
# 1311         0
# 1312         0
#
# [1313 rows x 5 columns]

# %%
#Количество точек данных (измерений) в наборе
len(df)
# Out:
# 1313

# %%
#Количество полей данных (атрибутов)
len(df.columns)
# Out:
# 5

# %%
#Тип данных каждого поля, шкала каждого поля
df.dtypes
# Out:
# Name         object
# PClass       object
# Age         float64
# Sex          object
# Survived      int64
# dtype: object

# %%
#Количество отсутствующих значений для каждого поля
df.isnull().sum()
# Out:
# Name          0
# PClass        1
# Age         557
# Sex           0
# Survived      0
# dtype: int64

# %%
#Удалить из набора поля, не несущие информативной нагрузки - содержащие уникальные либо константные значения
df.drop('Name', 1)
# Out:
# <ipython-input-37-c3263d7a2d67>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop('Name', 1)
#      PClass    Age     Sex  Survived
# 0       1st  29.00  female         1
# 1       1st   2.00  female         0
# 2       1st  30.00    male         0
# 3       1st  25.00  female         0
# 4       1st   0.92    male         1
# ...     ...    ...     ...       ...
# 1308    3rd  27.00    male         0
# 1309    3rd  26.00    male         0
# 1310    3rd  22.00    male         0
# 1311    3rd  24.00    male         0
# 1312    3rd  29.00    male         0
#
# [1313 rows x 4 columns]

# %%
#Заменить возраст пассажиров на год рождения
df['Age'] = 1912 - df['Age']
df
# Out:
#                                                Name PClass      Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  1883.00  female
# 1                       Allison, Miss Helen Loraine    1st  1910.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  1882.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  1887.00  female
# 4                     Allison, Master Hudson Trevor    1st  1911.08    male
# ...                                             ...    ...      ...     ...
# 1308                             Zakarian, Mr Artun    3rd  1885.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  1886.00    male
# 1310                               Zenni, Mr Philip    3rd  1890.00    male
# 1311                               Lievens, Mr Rene    3rd  1888.00    male
# 1312                                 Zimmerman, Leo    3rd  1883.00    male
#
#       Survived
# 0            1
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 1308         0
# 1309         0
# 1310         0
# 1311         0
# 1312         0
#
# [1313 rows x 5 columns]

# %%
#Переименовать все названия колонок на русском языке
df.columns = ['Имя', 'Класс', 'Год рождения', 'Пол', 'Выжил(а)']
df
# Out:
#                                                 Имя Класс  Год рождения  \
# 0                      Allen, Miss Elisabeth Walton   1st       1883.00
# 1                       Allison, Miss Helen Loraine   1st       1910.00
# 2               Allison, Mr Hudson Joshua Creighton   1st       1882.00
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)   1st       1887.00
# 4                     Allison, Master Hudson Trevor   1st       1911.08
# ...                                             ...   ...           ...
# 1308                             Zakarian, Mr Artun   3rd       1885.00
# 1309                         Zakarian, Mr Maprieder   3rd       1886.00
# 1310                               Zenni, Mr Philip   3rd       1890.00
# 1311                               Lievens, Mr Rene   3rd       1888.00
# 1312                                 Zimmerman, Leo   3rd       1883.00
#
#          Пол  Выжил(а)
# 0     female         1
# 1     female         0
# 2       male         0
# 3     female         0
# 4       male         1
# ...      ...       ...
# 1308    male         0
# 1309    male         0
# 1310    male         0
# 1311    male         0
# 1312    male         0
#
# [1313 rows x 5 columns]
